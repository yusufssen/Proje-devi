# %%
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLineEdit, QLabel

class AnaPencere(QWidget):
    def _init_(self):
        super()._init_()
        self.init_ui()

    def init_ui(self):
        self.setWindowTitle('Stok Yönetim Arayüzü')
        self.setGeometry(100, 100, 400, 300)

        self.urun_ekle_buton = QPushButton('Ürün Ekle', self)
        self.stok_durumu_buton = QPushButton('Stok Durumu', self)
        self.siparis_ver_buton = QPushButton('Sipariş Ver', self)

        self.urun_adi_input = QLineEdit(self)
        self.stok_miktari_input = QLineEdit(self)
        self.siparis_urun_adi_input = QLineEdit(self)
        self.siparis_miktari_input = QLineEdit(self)

        self.urun_ekle_buton.clicked.connect(self.urun_ekle)
        self.stok_durumu_buton.clicked.connect(self.stok_durumu)
        self.siparis_ver_buton.clicked.connect(self.siparis_ver)

        v_box = QVBoxLayout()
        v_box.addWidget(self.urun_adi_input)
        v_box.addWidget(self.stok_miktari_input)
        v_box.addWidget(self.urun_ekle_buton)
        v_box.addWidget(self.stok_durumu_buton)
        v_box.addWidget(self.siparis_urun_adi_input)
        v_box.addWidget(self.siparis_miktari_input)
        v_box.addWidget(self.siparis_ver_buton)

        self.setLayout(v_box)

    def urun_ekle(self):
        ad = self.urun_adi_input.text()
        miktar = int(self.stok_miktari_input.text())
        # Urun ekle işlevini burada çağırabilirsiniz

    def stok_durumu(self):
        # Stok durumu işlevini burada çağırabilirsiniz
        pass

    def siparis_ver(self):
        ad = self.siparis_urun_adi_input.text()
        miktar = int(self.siparis_miktari_input.text())
        # Sipariş ver işlevini burada çağırabilirsiniz


if _name_ == '_main_':
    app = QApplication(sys.argv)
    pencere = AnaPencere()
    pencere.show()
    sys.exit(app.exec_())
